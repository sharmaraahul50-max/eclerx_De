-- %%
create view if not exists workspace.gold.top_customers as
select customer_id, round(sum(total_amount)) as total_sales from workspace.silver.sales group by customer_id order by total_sales desc limit 3;

-- %%
select * from workspace.silver.sales;

-- %%
create schema if not exists workspace.gold;

-- %%
my name is rahul
