# %%
# %sql
select * from workspace.bronze.sales;

# %%
df=spark.read.table('workspace.bronze.sales');

# %%
df1=df.distinct().dropna();

# %%
# %sql
Create schema if not exists workspace.silver;

# %%
df1.write.mode('overwrite').saveAsTable('workspace.silver.sales')

# %%
# %sql
select * from workspace.silver.sales;
