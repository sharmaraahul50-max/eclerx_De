# %%
# %run "/Workspace/Users/sharmaraahul50@gmail.com/End to End Project _ DE/Includes"

# %%
Filename="sales"

# %%
Inputpath = "/Volumes/workspace/default/dev/"

# %%
df=spark.read.csv(f"{Inputpath}{Filename}",header=True,inferSchema=True);

# %%
add_ingestion_col(df)

# %%
# %sql
create schema if not exists workspace.bronze;

# %%
df=spark.read.csv(f"{Inputpath}{Filename}",header=True,inferSchema=True);
add_ingestion_col(df);
df.write.mode("overwrite").saveAsTable("workspace.bronze.sales");

# %%
# %sql
select * from workspace.bronze.sales
